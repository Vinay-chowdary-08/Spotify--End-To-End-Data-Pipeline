# %%
pip install spotipy
# Out:
# ...
#   Obtaining dependency information for spotipy from https://files.pythonhosted.org/packages/bd/3b/dde90e39c456f0d72397afd49d433f95c6a2fdbdcd829bcfc38cdbf6949a/spotipy-2.25.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for redis>=3.5.3 from https://files.pythonhosted.org/packages/13/67/e60968d3b0e077495a8fee89cf3f2373db98e528288a48f1ee44967f6e8c/redis-6.2.0-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.7/278.7 kB 4.7 MB/s eta 0:00:0000:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id = "42d978b2d527484d810fb1bb64578f47" , client_secret = "0fc9cd753dcd495d8e5b151832fd6a44")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link ="https://open.spotify.com/playlist/5ABHKGoOzxkaa28ttQV9sE"

# %%
playlist_uri = playlist_link.split("/")[-1].split("?")[0]

# %%
data = sp.playlist_tracks(playlist_uri)

# %%
data["items"][0]["track"]["album"]["id"]
# Out:
# '4yP0hdKOZPNshxUOjY0cZj'

# %%
data["items"][0]["track"]["album"]["name"]
# Out:
# 'After Hours'

# %%
data["items"][0]["track"]["album"]["release_date"]
# Out:
# '2020-03-20'

# %%
data["items"][0]["track"]["album"]["total_tracks"]
# Out:
# 14

# %%
data["items"][0]["track"]["album"]["external_urls"]["spotify"]
# Out:
# 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'

# %%
album_list = []
for row in data["items"]:
    album_id = row["track"]["album"]["id"]
    album_name = row["track"]["album"]["name"]
    album_release_date = row["track"]["album"]["release_date"]
    album_total_tracks = row["track"]["album"]["total_tracks"]
    album_url = row["track"]["album"]["external_urls"]["spotify"]
    album_element = {"album_id" : album_id , "name" : album_name , "release_date" : album_release_date , "total_tracks" : album_total_tracks , "url" : album_url }
    
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '4yP0hdKOZPNshxUOjY0cZj',
#   'name': 'After Hours',
#   'release_date': '2020-03-20',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'},
#  {'album_id': '3T4tUhGYeRNVUGevb0wThu',
#   'name': '÷ (Deluxe)',
#   'release_date': '2017-03-03',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu'},
#  {'album_id': '09fggMHib4YkOtwQNXEBII',
#   'name': 'Starboy',
#   'release_date': '2016-11-25',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/09fggMHib4YkOtwQNXEBII'},
#  {'album_id': '5658aM19fA3JVwTK6eQX70',
#   'name': 'Divinely Uninspired To A Hellish Extent',
#   'release_date': '2019-05-17',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/5658aM19fA3JVwTK6eQX70'},
#  {'album_id': '5r36AJ6VOJtp00oxSkBZ5h',
#   'name': "Harry's House",
#   'release_date': '2022-05-20',
#   'total_tracks': 13,
# ...

# %%
artist_list=[]
for row in data["items"]:
    for key,value in row.items():
        if key == "track":
            for artist in value["artists"]:
                artist_dict = {"artist_id" : artist["id"] , "artist_name": artist["name"], "external_url" : artist["href"] }
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '6eUKZXaKkcviH0Ku9w2n3V',
#   'artist_name': 'Ed Sheeran',
#   'external_url': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '4tZwfgrHOc3mvqYlEYSvVi',
#   'artist_name': 'Daft Punk',
#   'external_url': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi'},
#  {'artist_id': '4GNC7GD6oZMSxPGyXy4MNB',
#   'artist_name': 'Lewis Capaldi',
#   'external_url': 'https://api.spotify.com/v1/artists/4GNC7GD6oZMSxPGyXy4MNB'},
#  {'artist_id': '6KImCVD70vtIoJWnq6nGn3',
#   'artist_name': 'Harry Styles',
#   'external_url': 'https://api.spotify.com/v1/artists/6KImCVD70vtIoJWnq6nGn3'},
#  {'artist_id': '246dkjvS1zLTtiykXe5h60',
# ...

# %%
song_list = []
for row in data["items"]:
    song_id = row["track"]["id"]
    song_name = row["track"]["name"]
    song_duration = row["track"]["duration_ms"]
    song_url = row["track"]["album"]["external_urls"]["spotify"]
    song_popularity = row["track"]["popularity"]
    song_added = row["added_at"]
    album_id = row["track"]["album"]["id"]
    artist_id = row["track"]["album"]["artists"][0]["id"]
    song_element = {"song_id" : song_id, "song_name" : song_name, "song_duration" : song_duration, "url" : song_url, "popularity" :  song_popularity, "song_added" : song_added, "album_id" : album_id, "aritst_id": artist_id }
    
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '0VjIjW4GlUZAMYd2vXMi3b',
#   'song_name': 'Blinding Lights',
#   'song_duration': 200040,
#   'url': 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj',
#   'popularity': 91,
#   'song_added': '2024-02-15T21:57:53Z',
#   'album_id': '4yP0hdKOZPNshxUOjY0cZj',
#   'aritst_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'song_id': '7qiZfU4dY1lWllzX7mPBI3',
#   'song_name': 'Shape of You',
#   'song_duration': 233712,
#   'url': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu',
#   'popularity': 91,
#   'song_added': '2024-02-15T21:57:53Z',
#   'album_id': '3T4tUhGYeRNVUGevb0wThu',
#   'aritst_id': '6eUKZXaKkcviH0Ku9w2n3V'},
#  {'song_id': '5aAx2yezTd8zXrkmtKl66Z',
#   'song_name': 'Starboy',
#   'song_duration': 230453,
#   'url': 'https://open.spotify.com/album/09fggMHib4YkOtwQNXEBII',
#   'popularity': 6,
#   'song_added': '2024-02-15T21:57:53Z',
#   'album_id': '09fggMHib4YkOtwQNXEBII',
#   'aritst_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
# ...

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df
# Out:
#                   album_id                                               name  \
# 0   4yP0hdKOZPNshxUOjY0cZj                                        After Hours
# 1   3T4tUhGYeRNVUGevb0wThu                                         ÷ (Deluxe)
# 2   09fggMHib4YkOtwQNXEBII                                            Starboy
# 3   5658aM19fA3JVwTK6eQX70            Divinely Uninspired To A Hellish Extent
# 4   5r36AJ6VOJtp00oxSkBZ5h                                      Harry's House
# ..                     ...                                                ...
# 95  5D8Rdb09BkmHscEGSWAlA6                            Cold Heart (PNAU Remix)
# 96  2Ti79nwTsont5ZHfdxIzAm                                                  ?
# 97  7lCcQQC9Ft1qD70ALZWocC                                         JUST RIGHT
# 98  5VdyJkLe3yvOs0l4xXbWp0                                                 17
# 99  3pLdWdkj83EYfDN6H2N8MR  Black Panther The Album Music From And Inspire...
#
#    release_date  total_tracks  \
# ...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      100 non-null    object
#  1   name          100 non-null    object
#  2   release_date  100 non-null    object
#  3   total_tracks  100 non-null    int64
#  4   url           100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
album_df = album_df.drop_duplicates(subset = ["album_id"])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df
# Out:
#                   artist_id     artist_name  \
# 0    1Xyo4u8uXC1ZmMpatF05PJ      The Weeknd
# 1    6eUKZXaKkcviH0Ku9w2n3V      Ed Sheeran
# 2    1Xyo4u8uXC1ZmMpatF05PJ      The Weeknd
# 3    4tZwfgrHOc3mvqYlEYSvVi       Daft Punk
# 4    4GNC7GD6oZMSxPGyXy4MNB   Lewis Capaldi
# ..                      ...             ...
# 123  5YIiRsSWnafxIEmM0nsWOm      Paul James
# 124  38SHprY6NUd8O9LyWJ4hg4           RILEY
# 125  15UsOTVnJzReFVN1VCnxy4    XXXTENTACION
# 126  2YZyLoL8N0Wb9xBt1NhZWg  Kendrick Lamar
# 127  7tYKF4w9nC0nq9CsPZTHyP             SZA
#
#                                           external_url
# 0    https://api.spotify.com/v1/artists/1Xyo4u8uXC1...
# 1    https://api.spotify.com/v1/artists/6eUKZXaKkcv...
# 2    https://api.spotify.com/v1/artists/1Xyo4u8uXC1...
# 3    https://api.spotify.com/v1/artists/4tZwfgrHOc3...
# 4    https://api.spotify.com/v1/artists/4GNC7GD6oZM...
# ..                                                 ...
# ...

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_id     128 non-null    object
#  1   artist_name   128 non-null    object
#  2   external_url  128 non-null    object
# dtypes: object(3)
# memory usage: 3.1+ KB

# %%
artist_df = artist_df.drop_duplicates(subset = ["artist_id"])

# %%
song_df = pd.DataFrame.from_dict(song_list)
song_df
# Out:
#                    song_id                                          song_name  \
# 0   0VjIjW4GlUZAMYd2vXMi3b                                    Blinding Lights
# 1   7qiZfU4dY1lWllzX7mPBI3                                       Shape of You
# 2   5aAx2yezTd8zXrkmtKl66Z                                            Starboy
# 3   7qEHsqek33rTcFNT9PFqLf                                  Someone You Loved
# 4   4Dvkj6JhhA12EX05fT7y2e                                          As It Was
# ..                     ...                                                ...
# 95  6zSpb8dQRaw0M1dK8PBwQz                            Cold Heart - PNAU Remix
# 96  3ee8Jmje8o58CHK66QrVC2                                               SAD!
# 97  0V9qxaA0KkXeJqNEaj6dJC                                         JUST RIGHT
# 98  7m9OqQk4RVRkw9JJdeAw96                                     Jocelyn Flores
# 99  3GCdLUSnKSMJhs4Tj6CV3s  All The Stars (with SZA) - From "Black Panther...
#
# ...

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   song_id        100 non-null    object
#  1   song_name      100 non-null    object
#  2   song_duration  100 non-null    int64
#  3   url            100 non-null    object
#  4   popularity     100 non-null    int64
#  5   song_added     100 non-null    object
#  6   album_id       100 non-null    object
#  7   aritst_id      100 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 6.4+ KB

# %%
album_df
# Out:
#                   album_id                                               name  \
# 0   4yP0hdKOZPNshxUOjY0cZj                                        After Hours
# 1   3T4tUhGYeRNVUGevb0wThu                                         ÷ (Deluxe)
# 2   09fggMHib4YkOtwQNXEBII                                            Starboy
# 3   5658aM19fA3JVwTK6eQX70            Divinely Uninspired To A Hellish Extent
# 4   5r36AJ6VOJtp00oxSkBZ5h                                      Harry's House
# ..                     ...                                                ...
# 95  5D8Rdb09BkmHscEGSWAlA6                            Cold Heart (PNAU Remix)
# 96  2Ti79nwTsont5ZHfdxIzAm                                                  ?
# 97  7lCcQQC9Ft1qD70ALZWocC                                         JUST RIGHT
# 98  5VdyJkLe3yvOs0l4xXbWp0                                                 17
# 99  3pLdWdkj83EYfDN6H2N8MR  Black Panther The Album Music From And Inspire...
#
#    release_date  total_tracks  \
# ...

# %%
artist_df
# Out:
#                   artist_id    artist_name  \
# 0    1Xyo4u8uXC1ZmMpatF05PJ     The Weeknd
# 1    6eUKZXaKkcviH0Ku9w2n3V     Ed Sheeran
# 3    4tZwfgrHOc3mvqYlEYSvVi      Daft Punk
# 4    4GNC7GD6oZMSxPGyXy4MNB  Lewis Capaldi
# 5    6KImCVD70vtIoJWnq6nGn3   Harry Styles
# ..                      ...            ...
# 119  3PhoLpVuITZKcymswpck5b     Elton John
# 121  6n28c9qs9hNGriNa72b26u           PNAU
# 122  15UsOTVnJzReFVN1VCnxy4   XXXTENTACION
# 123  5YIiRsSWnafxIEmM0nsWOm     Paul James
# 124  38SHprY6NUd8O9LyWJ4hg4          RILEY
#
#                                           external_url
# 0    https://api.spotify.com/v1/artists/1Xyo4u8uXC1...
# 1    https://api.spotify.com/v1/artists/6eUKZXaKkcv...
# 3    https://api.spotify.com/v1/artists/4tZwfgrHOc3...
# 4    https://api.spotify.com/v1/artists/4GNC7GD6oZM...
# 5    https://api.spotify.com/v1/artists/6KImCVD70vt...
# ..                                                 ...
# ...

# %%
song_df
# Out:
#                    song_id                                          song_name  \
# 0   0VjIjW4GlUZAMYd2vXMi3b                                    Blinding Lights
# 1   7qiZfU4dY1lWllzX7mPBI3                                       Shape of You
# 2   5aAx2yezTd8zXrkmtKl66Z                                            Starboy
# 3   7qEHsqek33rTcFNT9PFqLf                                  Someone You Loved
# 4   4Dvkj6JhhA12EX05fT7y2e                                          As It Was
# ..                     ...                                                ...
# 95  6zSpb8dQRaw0M1dK8PBwQz                            Cold Heart - PNAU Remix
# 96  3ee8Jmje8o58CHK66QrVC2                                               SAD!
# 97  0V9qxaA0KkXeJqNEaj6dJC                                         JUST RIGHT
# 98  7m9OqQk4RVRkw9JJdeAw96                                     Jocelyn Flores
# 99  3GCdLUSnKSMJhs4Tj6CV3s  All The Stars (with SZA) - From "Black Panther...
#
# ...

# %%
album_df.loc[:,"release_date"] = pd.to_datetime(album_df["release_date"],format = "mixed" ,errors = "coerce")
song_df["song_added"] = pd.to_datetime(song_df["song_added"],format = "mixed" ,errors = "coerce")

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 92 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      92 non-null     object
#  1   name          92 non-null     object
#  2   release_date  92 non-null     datetime64[ns]
#  3   total_tracks  92 non-null     int64
#  4   url           92 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 4.3+ KB

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   song_id        100 non-null    object
#  1   song_name      100 non-null    object
#  2   song_duration  100 non-null    int64
#  3   url            100 non-null    object
#  4   popularity     100 non-null    int64
#  5   song_added     100 non-null    datetime64[ns, UTC]
#  6   album_id       100 non-null    object
#  7   aritst_id      100 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 6.4+ KB
